# %% [markdown]
# ## Quick start with _TemplateFlow Client_ API
#
# This notebook showcases elementary functionality of the _TemplateFlow_ API. We begin by importing the _TemplateFlow_ Python client.

# %%
import templateflow
import templateflow.api as tflow

print(f'Using TemplateFlow Client version {templateflow.__version__}')
# Out:
# Using TemplateFlow Client version 0.7.3.dev67+gb6cde5ad.d20220331

# %% [markdown]
# ### Finding templates
#
# At the time of writing, there are 15 templates available in the _TemplateFlow Archive_. We can use the `templates()` function to obtain the unique resource identifiers for all currently available templates.

# %%
templates = tflow.templates()

# Print template identifiers
ident_fmt = '\n'.join(templates)
print(f"{len(templates)} templates:\n-------------------\n{ident_fmt}")
# Out:
# 25 templates:
# -------------------
# Fischer344
# MNI152Lin
# MNI152NLin2009aAsym
# MNI152NLin2009aSym
# MNI152NLin2009bAsym
# MNI152NLin2009bSym
# MNI152NLin2009cAsym
# MNI152NLin2009cSym
# MNI152NLin6Asym
# MNI152NLin6Sym
# MNI305
# MNIColin27
# MNIInfant
# MNIPediatricAsym
# MouseIn
# NKI
# NMT31Sym
# OASIS30ANTs
# PNC
# RESILIENT
# UNCInfant
# VALiDATe29
# WHS
# fsLR
# fsaverage

# %% [markdown]
# ### Accessing metadata
#
# We can query metadata associated with individual data files (e.g., a volume or a surface) or general metadata of the template. For example, the method `get_metadata(<template_id>)` returns the general metadata as a dictionary:

# %%
# Get the full, general metadata dictionary for the Fischer344 rodent template
tflow.get_metadata('Fischer344')
# Out:
# {'Authors': ['Goerzen, D',
#   'Fowler, C',
#   'Devenyi, GA',
#   'Germann, J',
#   'Madularu, D',
#   'Chakravarty, MM',
#   'Near, J'],
#  'BIDSVersion': '1.1.0',
#  'Curators': ['MacNicol E', 'Esteban O'],
#  'Identifier': 'Fischer344',
#  'License': 'CC-by-nc-sa-4.0 International',
#  'Name': 'MRI-Derived Neuroanatomical Atlas of the Fischer 344 Rat Brain',
#  'ReferencesAndLinks': ['https://doi.org/10.5281/zenodo.3555555',
#   'https://doi.org/10.1038/s41598-020-63965-x'],
#  'Species': 'Rattus norvegicus',
#  'TemplateFlowVersion': '1.0.0'}

# %% [markdown]
# Accordingly, to obtain the usage license for any template, we can select the relevant field from the template's metadata dictionary.

# %%
# Get the usage license for the OASIS30ANTs template
tflow.get_metadata('OASIS30ANTs')['License']
# Out:
# 'CC BY 4.0'

# %% [markdown]
# Similarly, we can compile desired metadata from all templates. Below, we retrieve for each template its full name, the list of contributing authors, and the usage license.

# %%
import pandas as pd

metadata_fields = ['Name', 'Authors', 'License']
pd.DataFrame({col: [tflow.get_metadata(tpl)[col] for tpl in templates]
              for col in metadata_fields}, index=templates)
# Out:
#                                                                   Name  \
# Fischer344           MRI-Derived Neuroanatomical Atlas of the Fisch...
# MNI152Lin            Linear ICBM Average Brain (ICBM152) Stereotaxi...
# MNI152NLin2009aAsym  ICBM 152 Nonlinear Asymmetrical template versi...
# MNI152NLin2009aSym   ICBM 152 Nonlinear Symmetrical template versio...
# MNI152NLin2009bAsym  ICBM 152 Nonlinear Asymmetrical template versi...
# MNI152NLin2009bSym   ICBM 152 Nonlinear Symmetrical template versio...
# MNI152NLin2009cAsym  ICBM 152 Nonlinear Asymmetrical template versi...
# MNI152NLin2009cSym   ICBM 152 Nonlinear Symmetrical template versio...
# MNI152NLin6Asym      FSL's MNI ICBM 152 non-linear 6th Generation A...
# MNI152NLin6Sym       ICBM 152 non-linear 6th Generation Symmetric A...
# MNI305               MNI Average Brain (305 MRI) Stereotaxic Regist...
# MNIColin27           Colin 27 Average Brain, Stereotaxic Registrati...
# MNIInfant               MNI Unbiased nonlinear Infant Atlases 0-4.5yr.
# MNIPediatricAsym     MNI's unbiased standard MRI template for pedia...
# MouseIn              In Vivo MP2RAGE Templates of the C57Bl6/J Mous...
# NKI                                               ANTs' NKI-1 template
# NMT31Sym                         The NIMH Macaque Template v2 (NMT v2)
# OASIS30ANTs              OASIS30 - Generated with ANTs for MICCAI 2016
# PNC                    Philadelphia Neurodevelopmental Cohort template
# RESILIENT            Age-specific adult rat brain MRI templates and...
# UNCInfant                                     UNC Infant 0-1-2 Atlases
# VALiDATe29           The VALiDATe29 MRI Based Multi-Channel Atlas o...
# WHS                  Waxholm Space atlas of the Sprague Dawley rat ...
# fsLR                                      HCP Pipelines' fsLR template
# fsaverage                              FreeSurfer's fsaverage template
#
#                                                                Authors  \
# Fischer344           [Goerzen, D, Fowler, C, Devenyi, GA, Germann, ...
# MNI152Lin            [Evans AC, Fox PT, Lancaster J, Zilles K, Wood...
# MNI152NLin2009aAsym  [Fonov V, Evans AC, Botteron K, Almli CR, McKi...
# MNI152NLin2009aSym   [Fonov V, Evans AC, Botteron K, Almli CR, McKi...
# MNI152NLin2009bAsym  [Fonov V, Evans AC, Botteron K, Almli CR, McKi...
# MNI152NLin2009bSym   [Fonov V, Evans AC, Botteron K, Almli CR, McKi...
# MNI152NLin2009cAsym  [Fonov V, Evans AC, Botteron K, Almli CR, McKi...
# MNI152NLin2009cSym   [Fonov V, Evans AC, Botteron K, Almli CR, McKi...
# MNI152NLin6Asym                                             [Janke AL]
# MNI152NLin6Sym       [Grabner G, Janke AL, Budge MM, Smith D, Prues...
# MNI305                     [Collins DL, Neelin P, Peters TM, Evans AC]
# MNIColin27           [Holmes CJ, Hoge R, Collins DL, Woods R, Toga ...
# MNIInfant            [Fonov V, Evans AC, Botteron K, Almli CR, McKi...
# MNIPediatricAsym     [Fonov V, Evans AC, Botteron K, Almli CR, McKi...
# MouseIn                                 [Kim, E, MacNicol, E, Cash, D]
# NKI                  [Avants BB, Tustison NJ, Song G, Cook PA, Klei...
# NMT31Sym             [Jung, B., Taylor, P.A., Seidlitz, J., Sponhei...
# OASIS30ANTs          [Avants BB, Tustison NJ, Song G, Cook PA, Klei...
# PNC                  [Satterthwaite TD, Connolly JJ, Ruparel K, Cal...
# RESILIENT            [MacNicol, E, Wright, P, Kim, E, Brusini, I, E...
# UNCInfant            [Feng Shi, Pew-Thian Yap, Guorong Wu, Hongjun ...
# VALiDATe29           [Schilling K.G., Gao Y., Stepniewska I., Wu T....
# WHS                  [Papp EA, Leergaard TB, Calabrese E, Johnson G...
# fsLR                 [Tim Coalson, Matt Glasser, Mike Harms, David ...
# fsaverage                                                           []
#
#                                            License
# Fischer344           CC-by-nc-sa-4.0 International
# MNI152Lin                         See LICENSE file
# MNI152NLin2009aAsym               See LICENSE file
# MNI152NLin2009aSym                See LICENSE file
# MNI152NLin2009bAsym               See LICENSE file
# MNI152NLin2009bSym                See LICENSE file
# MNI152NLin2009cAsym               See LICENSE file
# MNI152NLin2009cSym                See LICENSE file
# MNI152NLin6Asym                   See LICENSE file
# MNI152NLin6Sym                    See LICENSE file
# MNI305                            See LICENSE file
# MNIColin27                        See LICENSE file
# MNIInfant                         See LICENSE file
# MNIPediatricAsym     MIT-derived. See LICENSE file
# MouseIn              CC-by-nc-sa-4.0 International
# NKI                                      CC BY 4.0
# NMT31Sym                             Public Domain
# OASIS30ANTs                              CC BY 4.0
# PNC                                      CC BY 4.0
# RESILIENT                  CC-BY-4.0 International
# UNCInfant                                    CC-BY
# VALiDATe29                                   CC-BY
# WHS                  CC-by-nc-sa-4.0 International
# fsLR                              See LICENSE file
# fsaverage                         See LICENSE file

# %% [markdown]
# The `get_citations` method allows for easy retrieval and formatting of references. By default, the method gives DOIs for each citation, but it can also be configured to return citations in BibTeX format. (This additionally requires the `doi2bib` package.)

# %%
print(tflow.get_citations('UNCInfant', bibtex=True)[0])
# Out:
# @article{Shi_2011,
# 	doi = {10.1371/journal.pone.0018746},
# 	url = {https://doi.org/10.1371%2Fjournal.pone.0018746},
# 	year = 2011,
# 	month = {apr},
# 	publisher = {Public Library of Science ({PLoS})},
# 	volume = {6},
# 	number = {4},
# 	pages = {e18746},
# 	author = {Feng Shi and Pew-Thian Yap and Guorong Wu and Hongjun Jia and John H. Gilmore and Weili Lin and Dinggang Shen},
# 	editor = {Hitoshi Okazawa},
# 	title = {Infant Brain Atlases from Neonates to 1- and 2-Year-Olds},
# 	journal = {{PLoS} {ONE}}
# }

# %% [markdown]
# #### Generating the LaTeX code listing all templates
# Let's automatically generate Supplementary Table S2 of the associated manuscript:

# %%
# LaTeX preamble
latex_src = [
    r"""\begin{table}[!th]
\begin{fullwidth}
\caption{\textbf{%
Digital templates included in \emph{TemplateFlow}.}
\emph{TemplateFlow} is designed to maximize the discoverability and accessibility of
  new templates, minimise redundancies in template creation,
  and promote standardization of processing workflows.
To enhance the visibility of existing templates, \emph{TemplateFlow} includes a 
  web-based browser indexing all files in the \emph{TemplateFlow Archive}
  (\url{templateflow.org/browse/}).
This table is generated automatically using the Jupyter Notebooks associated with this
  manuscript.
\label{tab:templates}}
\newcolumntype{C}[1]{>{\footnotesize\raggedright\let\newline\\\arraybackslash\hspace{0pt}}m{#1}}
\begin{tabular}{l C{.78\linewidth}}
\\
\toprule

\textbf{Template ID} & \textbf{Description} \\
\midrule
"""]

# Generate one row per template, gather citations
citations = []
for row, tpl in enumerate(templates):
    meta = tflow.get_metadata(tpl)
    if row % 2 != 0:
        latex_src.append(r"\rowcolor[HTML]{EEEEEE}")
        
    citation = ""
    
    rrid = meta.get('RRID', '').replace('_', '\\_')
    if rrid:
        rrid = f"RRID:{rrid}"
    
    refs = tflow.get_citations(tpl, bibtex=True)
    for citation in refs:
        if citation.startswith("http"):
            citation = "" if not rrid else f" ({rrid})"
            continue
        citations.append(citation)
        citation = f" \\citep{{{citation.split(',')[0].split('{')[-1].strip()}}}"
        if rrid:
            citation = citation.replace("citep", f"citep[{rrid};][]")
        break
    
    latex_src.append(f"""\\code{{{tpl}}} & {meta["Name"]}{citation}. \\\\""")

# LaTeX conclusion
latex_src.append(r"""
\bottomrule
\end{tabular}
\end{fullwidth}
\end{table}
""")
print("\n".join(latex_src))
print("BibTeX citations:\n" + "\n".join(sorted(set(citations))))
# Out:
# Failed to convert DOI <https://doi.org/10.1101/2020.09.16.30005> to bibtex, returning URL.
# \begin{table}[!th]
# \begin{fullwidth}
# \caption{\textbf{%
# Digital templates included in \emph{TemplateFlow}.}
# \emph{TemplateFlow} is designed to maximize the discoverability and accessibility of
#   new templates, minimise redundancies in template creation,
#   and promote standardization of processing workflows.
# To enhance the visibility of existing templates, \emph{TemplateFlow} includes a
#   web-based browser indexing all files in the \emph{TemplateFlow Archive}
#   (\url{templateflow.org/browse/}).
# This table is generated automatically using the Jupyter Notebooks associated with this
#   manuscript.
# \label{tab:templates}}
# \newcolumntype{C}[1]{>{\footnotesize\raggedright\let\newline\\\arraybackslash\hspace{0pt}}m{#1}}
# \begin{tabular}{l C{.78\linewidth}}
# \\
# \toprule
#
# \textbf{Template ID} & \textbf{Description} \\
# \midrule
#
# \code{Fischer344} & MRI-Derived Neuroanatomical Atlas of the Fischer 344 Rat Brain \citep{https://doi.org/10.5281/zenodo.3555555}. \\
# \rowcolor[HTML]{EEEEEE}
# \code{MNI152Lin} & Linear ICBM Average Brain (ICBM152) Stereotaxic Registration Model \citep{Mazziotta_1995}. \\
# \code{MNI152NLin2009aAsym} & ICBM 152 Nonlinear Asymmetrical template version 2009a \citep[RRID:SCR\_008796;][]{Fonov_2011}. \\
# \rowcolor[HTML]{EEEEEE}
# \code{MNI152NLin2009aSym} & ICBM 152 Nonlinear Symmetrical template version 2009a \citep[RRID:SCR\_008796;][]{Fonov_2011}. \\
# \code{MNI152NLin2009bAsym} & ICBM 152 Nonlinear Asymmetrical template version 2009b \citep[RRID:SCR\_008796;][]{Fonov_2011}. \\
# \rowcolor[HTML]{EEEEEE}
# \code{MNI152NLin2009bSym} & ICBM 152 Nonlinear Symmetrical template version 2009b \citep[RRID:SCR\_008796;][]{Fonov_2011}. \\
# \code{MNI152NLin2009cAsym} & ICBM 152 Nonlinear Asymmetrical template version 2009c \citep[RRID:SCR\_008796;][]{Fonov_2011}. \\
# \rowcolor[HTML]{EEEEEE}
# \code{MNI152NLin2009cSym} & ICBM 152 Nonlinear Symmetrical template version 2009c \citep[RRID:SCR\_008796;][]{Fonov_2011}. \\
# \code{MNI152NLin6Asym} & FSL's MNI ICBM 152 non-linear 6th Generation Asymmetric Average Brain Stereotaxic Registration Model \citep[RRID:SCR\_002823;][]{Evans_2012}. \\
# \rowcolor[HTML]{EEEEEE}
# \code{MNI152NLin6Sym} & ICBM 152 non-linear 6th Generation Symmetric Average Brain Stereotaxic Registration Model \citep[RRID:SCR\_008364;][]{Grabner_2006}. \\
# \code{MNI305} & MNI Average Brain (305 MRI) Stereotaxic Registration Model \citep{Collins_1994}. \\
# \rowcolor[HTML]{EEEEEE}
# \code{MNIColin27} & Colin 27 Average Brain, Stereotaxic Registration Model \citep{Holmes_1998}. \\
# \code{MNIInfant} & MNI Unbiased nonlinear Infant Atlases 0-4.5yr. \citep[RRID:SCR\_008796;][]{Fonov_2009}. \\
# \rowcolor[HTML]{EEEEEE}
# \code{MNIPediatricAsym} & MNI's unbiased standard MRI template for pediatric data from the 4.5 to 18.5y age range \citep[RRID:SCR\_008796;][]{Fonov_2011}. \\
# \code{MouseIn} & In Vivo MP2RAGE Templates of the C57Bl6/J Mouse Brain. \\
# \rowcolor[HTML]{EEEEEE}
# \code{NKI} & ANTs' NKI-1 template \citep{Avants_2011}. \\
# \code{NMT31Sym} & The NIMH Macaque Template v2 (NMT v2) \citep{Jung_2021}. \\
# \rowcolor[HTML]{EEEEEE}
# \code{OASIS30ANTs} & OASIS30 - Generated with ANTs for MICCAI 2016 \citep{Avants_2011}. \\
# \code{PNC} & Philadelphia Neurodevelopmental Cohort template \citep{Satterthwaite_2016}. \\
# \rowcolor[HTML]{EEEEEE}
# \code{RESILIENT} & Age-specific adult rat brain MRI templates and tissue probability maps \citep{MacNicol_2022}. \\
# \code{UNCInfant} & UNC Infant 0-1-2 Atlases \citep{Shi_2011}. \\
# \rowcolor[HTML]{EEEEEE}
# \code{VALiDATe29} & The VALiDATe29 MRI Based Multi-Channel Atlas of the Squirrel Monkey Brain \citep[RRID:SCR\_015542;][]{Schilling_2017}. \\
# \code{WHS} & Waxholm Space atlas of the Sprague Dawley rat brain \citep{Papp_2014}. \\
# \rowcolor[HTML]{EEEEEE}
# \code{fsLR} & HCP Pipelines' fsLR template \citep{Van_Essen_2011}. \\
# \code{fsaverage} & FreeSurfer's fsaverage template \citep{Fischl_1999}. \\
#
# \bottomrule
# \end{tabular}
# \end{fullwidth}
# \end{table}
#
# BibTeX citations:
# @article{Avants_2011,
# 	doi = {10.1016/j.neuroimage.2010.09.025},
# 	url = {https://doi.org/10.1016%2Fj.neuroimage.2010.09.025},
# 	year = 2011,
# 	month = {feb},
# 	publisher = {Elsevier {BV}},
# 	volume = {54},
# 	number = {3},
# 	pages = {2033--2044},
# 	author = {Brian B. Avants and Nicholas J. Tustison and Gang Song and Philip A. Cook and Arno Klein and James C. Gee},
# 	title = {A reproducible evaluation of {ANTs} similarity metric performance in brain image registration},
# 	journal = {{NeuroImage}}
# }
# @article{Collins_1994,
# 	doi = {10.1097/00004728-199403000-00005},
# 	url = {https://doi.org/10.1097%2F00004728-199403000-00005},
# 	year = 1994,
# 	month = {mar},
# 	publisher = {Ovid Technologies (Wolters Kluwer Health)},
# 	volume = {18},
# 	number = {2},
# 	pages = {192--205},
# 	author = {D. Louis Collins and Peter Neelin and Terrence M. Peters and Alan C. Evans},
# 	title = {Automatic 3D Intersubject Registration of {MR} Volumetric Data in Standardized Talairach Space},
# 	journal = {Journal of Computer Assisted Tomography}
# }
# @article{Evans_2012,
# 	doi = {10.1016/j.neuroimage.2012.01.024},
# 	url = {https://doi.org/10.1016%2Fj.neuroimage.2012.01.024},
# 	year = 2012,
# 	month = {aug},
# 	publisher = {Elsevier {BV}},
# 	volume = {62},
# 	number = {2},
# 	pages = {911--922},
# 	author = {Alan C. Evans and Andrew L. Janke and D. Louis Collins and Sylvain Baillet},
# 	title = {Brain templates and atlases},
# 	journal = {{NeuroImage}}
# }
# @article{Fischl_1999,
# 	doi = {10.1002/(sici)1097-0193(1999)8:4<272::aid-hbm10>3.0.co;2-4},
# 	url = {https://doi.org/10.1002%2F%28sici%291097-0193%281999%298%3A4%3C272%3A%3Aaid-hbm10%3E3.0.co%3B2-4},
# 	year = 1999,
# 	publisher = {Wiley},
# 	volume = {8},
# 	number = {4},
# 	pages = {272--284},
# 	author = {Bruce Fischl and Martin I. Sereno and Roger B.H. Tootell and Anders M. Dale},
# 	title = {High-resolution intersubject averaging and a coordinate system for the cortical surface},
# 	journal = {Human Brain Mapping}
# }
# @article{Fonov_2009,
# 	doi = {10.1016/s1053-8119(09)70884-5},
# 	url = {https://doi.org/10.1016%2Fs1053-8119%2809%2970884-5},
# 	year = 2009,
# 	month = {jul},
# 	publisher = {Elsevier {BV}},
# 	volume = {47},
# 	pages = {S102},
# 	author = {VS Fonov and AC Evans and RC McKinstry and CR Almli and DL Collins},
# 	title = {Unbiased nonlinear average age-appropriate brain templates from birth to adulthood},
# 	journal = {{NeuroImage}}
# }
# @article{Fonov_2011,
# 	doi = {10.1016/j.neuroimage.2010.07.033},
# 	url = {https://doi.org/10.1016%2Fj.neuroimage.2010.07.033},
# 	year = 2011,
# 	month = {jan},
# 	publisher = {Elsevier {BV}},
# 	volume = {54},
# 	number = {1},
# 	pages = {313--327},
# 	author = {Vladimir Fonov and Alan C. Evans and Kelly Botteron and C. Robert Almli and Robert C. McKinstry and D. Louis Collins},
# 	title = {Unbiased average age-appropriate atlases for pediatric studies},
# 	journal = {{NeuroImage}}
# }
# @article{Holmes_1998,
# 	doi = {10.1097/00004728-199803000-00032},
# 	url = {https://doi.org/10.1097%2F00004728-199803000-00032},
# 	year = 1998,
# 	month = {mar},
# 	publisher = {Ovid Technologies (Wolters Kluwer Health)},
# 	volume = {22},
# 	number = {2},
# 	pages = {324--333},
# 	author = {Colin J. Holmes and Rick Hoge and Louis Collins and Roger Woods and Arthur W. Toga and Alan C. Evans},
# 	title = {Enhancement of {MR} Images Using Registration for Signal Averaging},
# 	journal = {Journal of Computer Assisted Tomography}
# }
# @article{Jung_2021,
# 	doi = {10.1016/j.neuroimage.2021.117997},
# 	url = {https://doi.org/10.1016%2Fj.neuroimage.2021.117997},
# 	year = 2021,
# 	month = {jul},
# 	publisher = {Elsevier {BV}},
# 	volume = {235},
# 	pages = {117997},
# 	author = {Benjamin Jung and Paul A. Taylor and Jakob Seidlitz and Caleb Sponheim and Pierce Perkins and Leslie G. Ungerleider and Daniel Glen and Adam Messinger},
# 	title = {A comprehensive macaque {fMRI} pipeline and hierarchical atlas},
# 	journal = {{NeuroImage}}
# }
# @article{MacNicol_2022,
# 	doi = {10.3389/fninf.2021.669049},
# 	url = {https://doi.org/10.3389%2Ffninf.2021.669049},
# 	year = 2022,
# 	month = {jan},
# 	publisher = {Frontiers Media {SA}},
# 	volume = {15},
# 	author = {Eilidh MacNicol and Paul Wright and Eugene Kim and Irene Brusini and Oscar Esteban and Camilla Simmons and Federico E. Turkheimer and Diana Cash},
# 	title = {Age-Specific Adult Rat Brain {MRI} Templates and Tissue Probability Maps},
# 	journal = {Frontiers in Neuroinformatics}
# }
# @article{Mazziotta_1995,
# 	doi = {10.1006/nimg.1995.1012},
# 	url = {https://doi.org/10.1006%2Fnimg.1995.1012},
# 	year = 1995,
# 	month = {jun},
# 	publisher = {Elsevier {BV}},
# 	volume = {2},
# 	number = {2},
# 	pages = {89--101},
# 	author = {John C. Mazziotta and Arthur W. Toga and Alan Evans and Peter Fox and Jack Lancaster},
# 	title = {A Probabilistic Atlas of the Human Brain: Theory and Rationale for Its Development},
# 	journal = {{NeuroImage}}
# }
# @article{Papp_2014,
# 	doi = {10.1016/j.neuroimage.2014.04.001},
# 	url = {https://doi.org/10.1016%2Fj.neuroimage.2014.04.001},
# 	year = 2014,
# 	month = {aug},
# 	publisher = {Elsevier {BV}},
# 	volume = {97},
# 	pages = {374--386},
# 	author = {Eszter A. Papp and Trygve B. Leergaard and Evan Calabrese and G. Allan Johnson and Jan G. Bjaalie},
# 	title = {Waxholm Space atlas of the Sprague Dawley rat brain},
# 	journal = {{NeuroImage}}
# }
# @article{Satterthwaite_2016,
# 	doi = {10.1016/j.neuroimage.2015.03.056},
# 	url = {https://doi.org/10.1016%2Fj.neuroimage.2015.03.056},
# 	year = 2016,
# 	month = {jan},
# 	publisher = {Elsevier {BV}},
# 	volume = {124},
# 	pages = {1115--1119},
# 	author = {Theodore D. Satterthwaite and John J. Connolly and Kosha Ruparel and Monica E. Calkins and Chad Jackson and Mark A. Elliott and David R. Roalf and Ryan Hopson and Karthik Prabhakaran and Meckenzie Behr and Haijun Qiu and Frank D. Mentch and Rosetta Chiavacci and Patrick M.A. Sleiman and Ruben C. Gur and Hakon Hakonarson and Raquel E. Gur},
# 	title = {The Philadelphia Neurodevelopmental Cohort: A publicly available resource for the study of normal and abnormal brain development in youth},
# 	journal = {{NeuroImage}}
# }
# @article{Schilling_2017,
# 	doi = {10.1007/s12021-017-9334-0},
# 	url = {https://doi.org/10.1007%2Fs12021-017-9334-0},
# 	year = 2017,
# 	month = {jul},
# 	publisher = {Springer Science and Business Media {LLC}},
# 	volume = {15},
# 	number = {4},
# 	pages = {321--331},
# 	author = {Kurt G. Schilling and Yurui Gao and Iwona Stepniewska and Tung-Lin Wu and Feng Wang and Bennett A. Landman and John C. Gore and Li Min Chen and Adam W. Anderson},
# 	title = {The {VALiDATe}29 {MRI} Based Multi-Channel Atlas of the Squirrel Monkey Brain},
# 	journal = {Neuroinformatics}
# }
# @article{Shi_2011,
# 	doi = {10.1371/journal.pone.0018746},
# 	url = {https://doi.org/10.1371%2Fjournal.pone.0018746},
# 	year = 2011,
# 	month = {apr},
# 	publisher = {Public Library of Science ({PLoS})},
# 	volume = {6},
# 	number = {4},
# 	pages = {e18746},
# 	author = {Feng Shi and Pew-Thian Yap and Guorong Wu and Hongjun Jia and John H. Gilmore and Weili Lin and Dinggang Shen},
# 	editor = {Hitoshi Okazawa},
# 	title = {Infant Brain Atlases from Neonates to 1- and 2-Year-Olds},
# 	journal = {{PLoS} {ONE}}
# }
# @article{Van_Essen_2011,
# 	doi = {10.1093/cercor/bhr291},
# 	url = {https://doi.org/10.1093%2Fcercor%2Fbhr291},
# 	year = 2011,
# 	month = {nov},
# 	publisher = {Oxford University Press ({OUP})},
# 	volume = {22},
# 	number = {10},
# 	pages = {2241--2262},
# 	author = {D. C. Van Essen and M. F. Glasser and D. L. Dierker and J. Harwell and T. Coalson},
# 	title = {Parcellations and Hemispheric Asymmetries of Human Cerebral Cortex Analyzed on Surface-Based Atlases},
# 	journal = {Cerebral Cortex}
# }
# @incollection{Grabner_2006,
# 	doi = {10.1007/11866763_8},
# 	url = {https://doi.org/10.1007%2F11866763_8},
# 	year = 2006,
# 	publisher = {Springer Berlin Heidelberg},
# 	pages = {58--66},
# 	author = {GÃ¼nther Grabner and Andrew L. Janke and Marc M. Budge and David Smith and Jens Pruessner and D. Louis Collins},
# 	title = {Symmetric Atlasing and Model Based Segmentation: An Application to the Hippocampus in Older Adults},
# 	booktitle = {Medical Image Computing and Computer-Assisted Intervention {\textendash} {MICCAI} 2006}
# }
# @misc{https://doi.org/10.5281/zenodo.3555555,
#   doi = {10.5281/ZENODO.3555555},
#   url = {https://zenodo.org/record/3555555},
#   author = {Goerzen, Dana and Fowler, Caitlin and Devenyi, Gabriel and Germann, Jurgen and Madularu, Dan and Chakravarty, Mallar and Near, Jamie},
#   keywords = {Fischer 344 Rat, Structural MRI, Rat Brain Template, Digital Brain Atlas, MINC 2.0, NIfTI},
#   title = {An MRI-Derived Neuroanatomical Atlas of the Fischer 344 Rat Brain},
#   publisher = {Zenodo},
#   year = {2020},
#   copyright = {Creative Commons Attribution 4.0 International}
# }

# %% [markdown]
# ### Accessing data
#
# To retrieve the template resources themselves, we use the `get` method. This method accepts as arguments the unique template identifier together with any BIDS-like entities: key-value pairs specifying the resource to retrieve. It returns a path to the requested resource, which can (for example) be used with `nibabel` to read the resource into memory. The table below details valid entities for the API.
#
# |Data entity|API query example|Description|
# |:-|:-|:-|
# |Template|`"MNI152Lin"`|The template dataset to which an image or other data file belongs.|
# |Resolution|`resolution=1`|The image resolution. Each resolution is assigned a key, which is defined in the `res` field of `template_description.json`.|
# |Mask|`desc="brain", suffix="mask"`|Indicates that the image is a binary-valued annotation, where voxels labelled 1 are part of the mask.|
# |Discrete segmentation|`desc="malf", suffix="dseg"`|Indicates that the image is an integer-valued annotation. Each segmentation image file (`.nii.gz` format) is paired with a dictionary of segment names (`.tsv` format).|
# |Probabilistic segmentation|`label="CSF", suffix="probseg"`|Indicates that the image is a probabilistic annotation, wherein the value of each voxel indicates the probability of that voxel belonging to the specified label.|
# |Atlas|`atlas="Schaefer", desc="7Network"`|The atlas to which a segmentation file belongs.|
# |Transformation|`from="MNI152Lin", suffix="xfm"`|File containing a mapping between 2 stereotaxic coordinate spaces. The source space is defined in the `from` field, while the target space is defined in the `tpl` field.|
# |Image modality|`suffix="T1w"`|For non-annotation brain images, the suffix indicates whether the image is T1-weighted (`T1w`), T2-weighted (`T2w`), proton density-weighted (`PD`), or T2*-weighted (`T2star`).|
# |Template cohort|`cohort=1`|Subsample of a dataset used to generate an average template.|
#
# _TemplateFlow_ uses a lazy loading scheme for resource retrieval: at installation, the local copy of the archive tree contains only pointers to cloud-based resources. As data resources are requested (for instance using the `get` method), they are synced from the cloud to the local file system. If the data have already been downloaded, they can be retrieved from the local system cache without repeating the download.
#
# As an example, we can use the `get` method to retrieve a path to the 100-node Schaefer atlas.

# %%
print(tflow.get(
    'MNI152NLin2009cAsym',
    resolution=1,
    atlas='Schaefer2018',
    desc='100Parcels7Networks',
))
# Out:
# /Users/oesteban/.cache/templateflow/tpl-MNI152NLin2009cAsym/tpl-MNI152NLin2009cAsym_res-01_atlas-Schaefer2018_desc-100Parcels7Networks_dseg.nii.gz

# %% [markdown]
# ...or the T1-weighted `MNI152NLin6Asym` template.

# %%
print(tflow.get(
    "MNI152NLin6Asym",
    desc=None,
    resolution=1,
    suffix="T1w"
))
# Out:
# /Users/oesteban/.cache/templateflow/tpl-MNI152NLin6Asym/tpl-MNI152NLin6Asym_res-01_T1w.nii.gz

# %% [markdown]
# By omitting arguments, we retrieve any data that match the remaining (specified) arguments.

# %%
tflow.get("MNI152NLin6Asym", resolution=1, suffix='probseg')
# Out:
# [PosixPath('/Users/oesteban/.cache/templateflow/tpl-MNI152NLin6Asym/tpl-MNI152NLin6Asym_res-01_atlas-HOCPA_probseg.nii.gz'),
#  PosixPath('/Users/oesteban/.cache/templateflow/tpl-MNI152NLin6Asym/tpl-MNI152NLin6Asym_res-01_atlas-HOCPAL_probseg.nii.gz'),
#  PosixPath('/Users/oesteban/.cache/templateflow/tpl-MNI152NLin6Asym/tpl-MNI152NLin6Asym_res-01_atlas-HOSPA_probseg.nii.gz')]

# %% [markdown]
# ### Integrating _TemplateFlow_ into processing workflows
#
#
# #### Motivation
#
# _TemplateFlow_ maximizes the accessibility and reuse potential of templates and atlases. For example, let's reuse the base configuration file for FSL FEAT we proposed in our paper (Esteban et al., 2019). The design file `design.fsf` specifies a simple preprocessing workflow with FSL tools. The simplified code listing below shows that, just to make non-default templates available to FSL using the graphical user interface (GUI), at least five steps are necessary:
# ```bash
# # 1. User determines two nondefault templates they want to spatially normalize into
# # 2. User manually downloads templates, extracts the required files from packages
# $ curl -sSL <url> | tar zxv --no-same-owner -C /data/templates/
# # 3. User opens FSL's GUI, edits the target template box content pointing to the appropriate files
# # 4. User generates FSL configuration files to permit batch execution on the command line
# # 5. For the default and the two nondefault templates, execute FSL's feat:
# $ feat design_<template>.fsf
# ```
#
# The outputs of each `feat design_<template>.fsf` call will follow the pre-specified patterns of FSL, with whatever customization the user has introduced into the design file. The user, therefore, must then adapt the downstream analysis tools to correctly interpret the derived dataset, in each standard space, or reformat the output dataset according to the expectations of the analysis tools.
#
# The user is also responsible for all aspects of provenance tracking and adequately reporting them in their communications. Information such as version of the template (or download date), citations to relevant papers, and other metadata (e.g., RRIDs) must be accounted for manually throughout the research process.
#
# <hr>

# %% [markdown]
# #### _TemplateFlow_ integration with `fMRIPrep`
#
# In contrast, tools using _TemplateFlow_ dramatically simplify the whole process (note that `MNI152NLin2009cAsym` and `OASIS30Ants` are the two templates not found within the FSL distribution, and `MNI152NLin6Asym` denotes _FSL's MNI space_ (i.e., the default FSL template):
#
# ```bash
# $ fmriprep /data /derivatives participant --output-spaces MNI152NLin2009cAsym MNI152NLin6Asym OASIS30Ants
# ```
#
# _fMRIPrep_ generates the results with BIDS-Derivatives organization for the three templates. The tool also leverages _TemplateFlow_ to generate a _boilerplate citation text_ that includes the full names, versions and references to credit the template's authors for each of the templates involved.
#
# _fMRIPrep_ internally stages one spatial normalization workflow for each of the output spaces. Each of these normalization sub-workflows uses a simple line of Python code to retrieve the necessary resources from _TemplateFlow_ using the _TemplateFlow Client_ interface:

# %%
tpl_ref_file = tflow.get("MNI152NLin6Asym", desc=None, resolution=1, suffix="T1w")
print(tpl_ref_file)
# Out:
# /Users/oesteban/.cache/templateflow/tpl-MNI152NLin6Asym/tpl-MNI152NLin6Asym_res-01_T1w.nii.gz

# %% [markdown]
# <hr>
#
# #### Obtaining templates for registration
#
# Outside of `fMRIPrep`, we can also use _TemplateFlow_ to streamline workflows that make use of standard spatial references, including (for instance) registration and segmentation workflows. For example, we can use an inline call to the Python client to retrieve the template (or, as necessary, a mask or tissue probability map) to build a call to SyN-based ANTs registration in a short bash script:)

# %%
# %%bash
#
# templates=(
#     MNI152NLin2009cAsym
#     MNI152NLin6Asym
#     OASIS30ANTs
# )
#
# for template in ${templates[@]}
#     do
#     template_path=$(
#         python -c "
# import templateflow.api as tflow
# print(tflow.get('${template}', desc=None, resolution=1, suffix='T1w'))
#         "
#     )
#     echo antsRegistrationSyN.sh \
#         -d 3 \
#         -f $template_path \
#         -m /data/ds-001/sub-001/ses-001/sub-001_ses-001_T1w.nii.gz \
#         -o /tmp/sub-001_ses-001_space-${template}_T1w
#     echo
# done
# Out:
# antsRegistrationSyN.sh -d 3 -f /Users/oesteban/.cache/templateflow/tpl-MNI152NLin2009cAsym/tpl-MNI152NLin2009cAsym_res-01_T1w.nii.gz -m /data/ds-001/sub-001/ses-001/sub-001_ses-001_T1w.nii.gz -o /tmp/sub-001_ses-001_space-MNI152NLin2009cAsym_T1w
#
# antsRegistrationSyN.sh -d 3 -f /Users/oesteban/.cache/templateflow/tpl-MNI152NLin6Asym/tpl-MNI152NLin6Asym_res-01_T1w.nii.gz -m /data/ds-001/sub-001/ses-001/sub-001_ses-001_T1w.nii.gz -o /tmp/sub-001_ses-001_space-MNI152NLin6Asym_T1w
#
# antsRegistrationSyN.sh -d 3 -f /Users/oesteban/.cache/templateflow/tpl-OASIS30ANTs/tpl-OASIS30ANTs_res-01_T1w.nii.gz -m /data/ds-001/sub-001/ses-001/sub-001_ses-001_T1w.nii.gz -o /tmp/sub-001_ses-001_space-OASIS30ANTs_T1w

# %% [markdown]
# <hr>
#
# #### Masks
#
# One detail glossed over in the FSL example above is that, for a robust spatial normalization process, a precise binary mask of the brain is generally used. While FSL would require the user to manually set this mask up in the GUI, in the case of _TemplateFlow_, it requires a second minimal call:

# %%
msk_ref_file = tflow.get("MNI152NLin6Asym", desc="brain", resolution=1, suffix="mask")
print(msk_ref_file)
# Out:
# /Users/oesteban/.cache/templateflow/tpl-MNI152NLin6Asym/tpl-MNI152NLin6Asym_res-01_desc-brain_mask.nii.gz

# %% [markdown]
# These examples are extreme simplifications of what a pipeline developer can automate and make more robust by integrating _TemplateFlow_ in their workflows.

# %% [markdown]
# <hr>
#
# ### Summary
#
# _TemplateFlow_ makes many aspects of working with spatial standard datasets easier. Please check out the [_TemplateFlow_ homepage](https://www.templateflow.org/) and the detailed [documentation hub](https://www.templateflow.org/python-client/master/index.html#) for _TemplateFlow_ for further information about using the client or contributing new template resources. If you still have questions, you can ask on [NeuroStars](https://neurostars.org/tag/templateflow) with the `templateflow` tag.
